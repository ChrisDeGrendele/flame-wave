# %% [markdown]
# Todo:
# * Change flame_speed to measure the average of x direction cells, rather than the x of the max. - Does this converge?? Right now, with the max it doesn't. One other solution would be to put it on a "treadmill" and run it for significantly longer so if there are differing speeds, they have time to seperate.
# * Implement "Compare flame speed"
# * Test if issue #132 is still a problem
# * Flame fails on burner integration.

# %% [markdown]
# We track the flame by defining the 'front' as the highest value of nuclear energy generation
# (H_nuc). (Schwab et. at al 2020 (arXiv:2001.0773) https://arxiv.org/abs/2001.07733 )

# %%
import yt
from yt.funcs import mylog
mylog.setLevel(40) # Gets rid of all of the yt info text, only errors.
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import os
from IPython.display import Video

# %%
def make_movie(file_list, save_dir='tmp/', var='rho', movie_name="movie.mp4"):
    i = 1
    for file in file_list:
        ds = yt.load(file)
        sl = yt.SlicePlot(ds,2,var)
        sl.save("movie_imag{}.png".format(str(i).zfill(4)))
        i+=1
    os.system("ffmpeg -r 60 -pattern_type glob -i 'movie_imag*.png' -vcodec mpeg4 -y {}".format(movie_name))
    os.system("rm movie_imag*")
    Video("movie.mp4", embed=True)
    
def flame_speed(file_list):
    Hnucs = []
    xs = []
    ys = []
    zs = []
    ts = []
    rs = []
    for file in file_list:
        ds = yt.load(file)
        ad = ds.all_data()
        #sl = yt.SlicePlot(ds,2,'Hnuc')
        #profile_2d = yt.create_profile(ad, ['x', 'y'], 'Hnuc', weight_field=None)
        #Save Data:
        x,y,z = ad.argmax("Hnuc")
        Hnucs.append(ad.quantities.extrema("Hnuc"))
        xs.append(x)
        ys.append(y)
        zs.append(z)
        ts.append(ds.current_time)
        
        #Another option is to average the ys along the x and take the max of that.
        # To do this we create bins along the x direction

        #The following bins by y, and with a weighted field of None, 
        #For each y, we are just summing up all of Hnuc horizontally across.
        profile = ad.profile("y", "Hnuc", weight_field=None)    
        #index of the max value of Hnuc
        index = profile.items()[0][1].argmax()
        #location of the max value
        flame_loc = profile.x[index]
        rs.append(flame_loc)
        




        
    #The below "r" where we track Hnuc, can look very bumpy, because Hnuc, could be 
    #in the same y location (~ distance traveled in a long skinny domain), but could
    #be moving around in the x direction. 
    #r = [np.sqrt(xs[i]**2 + ys[i]**2 + zs[i]**2) for i in range(len(xs))]
    
    #So - Lets just take the y component. Z should always be zero in 2D anyways. 
    #r = ys
    
        
    r = rs
    
    v = np.diff(r)/(ts[1]-ts[0])
    
    #Convert YTArrays to regular arrays
    #For r and t, it wasn't a YT array, just units, so we need 
    #to convert there and back.
    return yt.YTArray(ts).base, yt.YTArray(r).base, v.base
    
    
def flame_plot(ts,r,v):    
    plt.plot(ts,r)
    plt.gca().ticklabel_format(axis='both', style='sci', scilimits=(-1,1))
    plt.xlabel("Time [Seconds]")
    plt.ylabel("Distance Traveled by Flame [cm]")
    plt.show()
    
    plt.plot(ts[1:],v)
    plt.xlabel("Time [Seconds]")
    plt.ylabel("Velocity [cm/sec]")
    plt.gca().ticklabel_format(axis='both', style='sci', scilimits=(-1,1))

def compare_flame_speed(file_list1, file_list2):
    '''for comparing two file_list's flamespeeds'''

# %% [markdown]
# Some notes about a choice of how to track the flame speed.
#
# So far I've explored 3 ways.
# 1. Take the max Hnuc location and track it by drawing straight lines in between points. This way looked really bumpy, probably because the path was oscillating back in forth in the x direction, where the max could be anywhere along that flame front.
# 2. To combat this, I looked at just the y location of the max. This was very smooth, but did not converge to a value as more AMR values were added.
#
#  * 1 AMR Level,  speed =  95793.24367283349 cm/s
#  * 2 AMR Levels, speed =  95776.11510202265 cm/s
#  * 3 AMR Levels, speed =  95832.56655976942 cm/s
#  * 4 AMR Levels, speed =  93824.0571893065 cm/s
#
#
# 3. The third way, is binning by the y value. This sums up the Hnuc values for each y value at all the x values. So, for example at y = 0, we sum all the x values of Hnuc along the x axis. We then have a function of y vs Hnuc. Taking the max of this binned approach gives us the y location of our flame. This at least shows a general direction of convergence? But its not getting smaller... In josiah's paper they showed as they increase isotopes, the flame gets faster. I wonder if this is a similiar effect? More resolution = faster?
#
#  * 1 AMR Level,  speed =  96380.15274631289 cm/s
#  * 2 AMR Levels, speed =  97482.1075264618 cm/s
#  * 3 AMR Levels, speed =  98194.97960251856 cm/s
#  * 4 AMR Levels, speed =  99229.99858875212 cm/s

# %%
'''
flames = np.sort(glob.glob("A path *"))
make_movie(flames, movie_name='strang.mp4', var="Hnuc" )
Video("strang.mp4")
'''
# Out:
# '\nflames = np.sort(glob.glob("A path *"))\nmake_movie(flames, movie_name=\'strang.mp4\', var="Hnuc" )\nVideo("strang.mp4")\n'

# %%
#Strang:
lvl0_strang = np.sort(glob.glob("data/flame_convergence/lvl0_flame*"))[:-3] #cut off the three initial plots
lvl1_strang = np.sort(glob.glob("data/flame_convergence/lvl1_flame*"))[:-3]
lvl2_strang = np.sort(glob.glob("data/flame_convergence/lvl2_flame*"))[:-3]
lvl3_strang = np.sort(glob.glob("data/flame_convergence/lvl3_flame*"))[:-4] #for some reason the last plot file has trouble

#SDC 
lvl0_sdc = np.sort(glob.glob("data/flame_convergence_sdc/lvl0_sdc_flame_*"))[:-3]

# %% [markdown]
# # Convergence -  Strang integration

# %%
t, r, v = flame_speed(lvl0_strang)
plt.plot(t,r, label='amr.max_level=0', linewidth=1.0)
a, b = np.polyfit(t,r,1)
print("1 AMR Level,  speed = ", a, "cm/s")

t, r, v = flame_speed(lvl1_strang)
plt.plot(t,r, label='amr.max_level=1', linewidth=1.0)
a, b = np.polyfit(t,r,1)
print("2 AMR Levels, speed = ", a, "cm/s")

t, r, v = flame_speed(lvl2_strang)
plt.plot(t,r, label='amr.max_level=2', linewidth=1.0)
a, b = np.polyfit(t,r,1)
print("3 AMR Levels, speed = ", a, "cm/s")

t, r, v = flame_speed(lvl3_strang)
plt.plot(t,r, label='amr.max_level=3', linewidth=1.0)
a, b = np.polyfit(t,r,1)
print("4 AMR Levels, speed = ", a, "cm/s")

plt.gca().ticklabel_format(axis='both', style='sci', scilimits=(-1,1))
plt.xlabel("Time [Seconds]")
plt.ylabel("Distance Traveled by Flame [cm]")
plt.legend()
plt.show()
# Out:
# 1 AMR Level,  speed =  96380.15274631289 cm/s
# 2 AMR Levels, speed =  97482.1075264618 cm/s
# 3 AMR Levels, speed =  98194.97960251856 cm/s
# 4 AMR Levels, speed =  99229.99858875212 cm/s

# %%
t, r, v = flame_speed(lvl0_strang)
plt.plot(t,r, label='Strang 1 level')
t, r, v = flame_speed(lvl0_sdc)
plt.plot(t,r, label='Sdc 1 level')
plt.gca().ticklabel_format(axis='both', style='sci', scilimits=(-1,1))
plt.xlabel("Time [Seconds]")
plt.ylabel("Distance Traveled by Flame [cm]")
plt.legend()
plt.show()

# %% [markdown]
# # Electron Capture Flame Speed

# %%
lvl0_ec = np.sort(glob.glob("data/flame_electroncapture/lvl0*"))[:-4]
t, r, v = flame_speed(lvl0_ec)
plt.plot(t,r, label='amr.max_level=0')
a, b = np.polyfit(t,r,1)
#print("1 AMR Level,  speed = ", a, "cm/s")

# %%
make_movie(lvl0_ec, movie_name='lvl0_ec.mp4', var="Hnuc" )

# %%
Video("lvl0_ec.mp4", height=500)
# Out:
# <video src="lvl0_ec.mp4" controls   height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
for plt in lvl0_strang:
    ds = yt.load(plt)
    ad = ds.all_data()
    profile = ad.profile("y", "Hnuc", weight_field=None)      # profile field
    print(profile.x.max())
    p = profile.plot()
    p.set_log("y", False)
    p.show()
# Out:
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# 4.716933235956836 cm
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %%
ds.field_list
# Out:
# [('boxlib', 'Hnuc'),
#  ('boxlib', 'MachNumber'),
#  ('boxlib', 'Pi'),
#  ('boxlib', 'S'),
#  ('boxlib', 'X(C12)'),
#  ('boxlib', 'X(Mg24)'),
#  ('boxlib', 'X(O16)'),
#  ('boxlib', 'abar'),
#  ('boxlib', 'conductivity'),
#  ('boxlib', 'deltaT'),
#  ('boxlib', 'deltagamma'),
#  ('boxlib', 'deltap'),
#  ('boxlib', 'divw0'),
#  ('boxlib', 'entropy'),
#  ('boxlib', 'entropypert'),
#  ('boxlib', 'gpix'),
#  ('boxlib', 'gpiy'),
#  ('boxlib', 'h'),
#  ('boxlib', 'h0'),
#  ('boxlib', 'magvel'),
#  ('boxlib', 'momentum'),
#  ('boxlib', 'omegadot(C12)'),
#  ('boxlib', 'omegadot(Mg24)'),
#  ('boxlib', 'omegadot(O16)'),
#  ('boxlib', 'p0'),
#  ('boxlib', 'p0pluspi'),
#  ('boxlib', 'pioverp0'),
#  ('boxlib', 'rho'),
#  ('boxlib', 'rho0'),
#  ('boxlib', 'rhoX(C12)'),
#  ('boxlib', 'rhoX(Mg24)'),
#  ('boxlib', 'rhoX(O16)'),
#  ('boxlib', 'rhoh'),
#  ('boxlib', 'rhoh0'),
#  ('boxlib', 'rhohpert'),
#  ('boxlib', 'rhopert'),
#  ('boxlib', 'tfromh'),
#  ('boxlib', 'tfromp'),
#  ('boxlib', 'thermal'),
# ...

# %%
profile.x
# Out:
# YTArray([2.59584109e-03, 2.92424879e-03, 3.29420434e-03, 3.71096409e-03,
#          4.18044937e-03, 4.70933065e-03, 5.30512230e-03, 5.97628936e-03,
#          6.73236779e-03, 7.58409998e-03, 8.54358738e-03, 9.62446244e-03,
#          1.08420823e-02, 1.22137469e-02, 1.37589449e-02, 1.54996306e-02,
#          1.74605357e-02, 1.96695208e-02, 2.21579713e-02, 2.49612432e-02,
#          2.81191656e-02, 3.16766062e-02, 3.56841093e-02, 4.01986138e-02,
#          4.52842619e-02, 5.10133108e-02, 5.74671589e-02, 6.47375028e-02,
#          7.29276399e-02, 8.21539360e-02, 9.25474787e-02, 1.04255940e-01,
#          1.17445674e-01, 1.32304081e-01, 1.49042270e-01, 1.67898058e-01,
#          1.89139349e-01, 2.13067939e-01, 2.40023808e-01, 2.70389945e-01,
#          3.04597795e-01, 3.43133382e-01, 3.86544223e-01, 4.35447101e-01,
#          4.90536829e-01, 5.52596126e-01, 6.22506732e-01, 7.01261940e-01,
#          7.89980707e-01, 8.89923553e-01, 1.00251047e+00, 1.12934110e+00,
# ...

# %%
ds = yt.load(lvl0_strang[0])
ad = ds.all_data()
profile = ad.profile("y", "Hnuc", weight_field=None)      # profile field
p = profile.plot()
p.set_log("y", False)
p.show()

profile
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
profile.items()[0][1].argmax()
# Out:
# 48

# %%
profile.x[48]
# Out:
# 0.7899807066882139 cm

# %%
t, r, v = flame_speed(lvl0_strang)

# %%
r
# Out:
# array([0.78998071, 0.78998071, 0.88992355, 0.88992355, 1.00251047,
#        1.00251047, 1.1293411 , 1.1293411 , 1.1293411 , 1.27221746,
#        1.27221746, 1.43316953, 1.43316953, 1.43316953, 1.61448414,
#        1.61448414, 1.61448414, 1.61448414, 1.81873741, 1.81873741,
#        1.81873741, 1.81873741, 2.04883137, 2.04883137, 2.04883137,
#        2.04883137, 2.30803522, 2.30803522, 2.30803522, 2.30803522,
#        2.30803522, 2.60003173])

# %%
t
# Out:
# array([0.00000000e+00, 4.01866681e-07, 1.00003716e-06, 1.59954703e-06,
#        2.19996212e-06, 2.80105111e-06, 3.40267084e-06, 4.00472503e-06,
#        4.60714428e-06, 5.20987681e-06, 5.81288242e-06, 6.41612888e-06,
#        7.01959015e-06, 7.62324463e-06, 8.22707407e-06, 8.83106291e-06,
#        9.43519777e-06, 1.00152938e-05, 1.00394670e-05, 1.06438605e-05,
#        1.12483691e-05, 1.18529848e-05, 1.24577005e-05, 1.30625096e-05,
#        1.36674064e-05, 1.42723854e-05, 1.48774419e-05, 1.54825713e-05,
#        1.60877696e-05, 1.66930329e-05, 1.72983578e-05, 1.79037410e-05])

# %%
t, r, v = flame_speed(lvl0_strang)
yt.LinePlot(t,r, label='amr.max_level=0', linewidth=9.0)
a, b = np.polyfit(t,r,1)
print("1 AMR Level,  speed = ", a, "cm/s")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-4762cc8c191d> in <module>
#       1 t, r, v = flame_speed(lvl0_strang)
# ----> 2 yt.LinePlot(t,r, label='amr.max_level=0', linewidth=9.0)
#       3 a, b = np.polyfit(t,r,1)
#       4 print("1 AMR Level,  speed = ", a, "cm/s")
#       5
#
# TypeError: __init__() got an unexpected keyword argument 'label'

# %%
v.base

# %%
t, r, v = flame_speed(lvl0_strang)

# %%
plt.plot(t,r)

# %%
t = np.array(t)
r  = np.array(r)

# %%
ts = []
rs = []
for i in range(1,len(t)):
    ts.append(t[i])
    rs.append(r[i])

# %%
plt.plot(ts,rs)

# %%
type(ts[1])
